# %%
import seaborn as sns
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
sns.set()
data = sns.load_dataset('tips')

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#dans l'ordre:
#nombre total,
#moyenne,
#écart oyen face à la moyenne, 
#valeur minimum , 
# premier quartile: la valeur telle que 25% des valeurs notées y sont inférieurs
# second quartile: la valeur telle que 50% des valeurs notées y sont inférieurs
# troisieme quartile: la valeur telle que 75% des valeurs notées y sont inférieurs
# valeur maximale

# %%
data = pd.read_csv("data/house_pricing.csv")

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# il y a 81 variable, en trois type : gloat, int et object, elles sont qualitative?

# %%
data.plot.scatter(y='LotArea',x='SalePrice')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# les données sont visualisées sous un graph prix par emplacement

# %%
data = sns.relplot(x='LotArea', y='SalePrice', data=data)

# %%
data = pd.read_csv("data/house_pricing.csv")
#datatest = pd.DataFrame(data, columns = ['SalePrice', 'LotArea'])
datatest2 = data[data.LotArea<20000][data.SalePrice<500000]
sns.relplot(x='LotArea', y='SalePrice', data=datatest2)

# %%
sns.relplot(x='LotFrontage', y='LotArea', data=data)

# %%
datatest3 = data[data.LotFrontage<200][data.SalePrice<100000]
sns.relplot(x='LotArea', y='SalePrice', data=datatest3)
